# %% [markdown]
# # Problemas de prueba de hipótesis

# %% [markdown]
# ## Ejercicio 1
#
# Usted es un nutricionista que investiga dos tipos diferentes de dietas para ver si existe una diferencia significativa en la pérdida de peso después de un mes. Eliges dos grupos aleatorios de personas; un grupo sigue la primera dieta y el otro sigue la segunda. Al final del mes, se registra la pérdida de peso (en kg) de cada persona:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# Con estos datos se busca responder a la siguiente pregunta: ¿Existe una diferencia significativa en la pérdida de peso promedio entre las personas que siguieron la primera dieta y las que siguieron la segunda dieta?
#
# Para sacar conclusiones, siga los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba para comprobar la hipótesis. Puede utilizar la prueba t de Student.
# -Analizar las conclusiones.

# %%
#1. Enunciamos las hipótesis
#Hipótesis Nula (H0): No hay diferencia significativa entre las dietas.
#Hipótesis Alternativa (H1): Hay una diferencia significativa entre las dietas.

# %%
# 2.Realicemos los datos de calculo 
# Extraer los datos estadisticos básicos 
# Métrica     Dieta 1                                Dieta 2
# Datos       2.0, 2.5, 3.0, 2.8, 2.3, 2.7, 2.5      3.0, 3.2, 3.1, 2.9, 2.8, 3.0, 3.2
# Tamaño muestra  7                                  7

# %%
import scipy.stats as stats

dieta1 = [2.0, 2.5, 3.0, 2.8, 2.3, 2.7, 2.5]
dieta2 = [3.0, 3.2, 3.1, 2.9, 2.8, 3.0, 3.2]

t_stat, p_value = stats.ttest_ind(dieta1, dieta2)

print(f"Estadístico t: {t_stat:.4f}")
print(f"P-valor: {p_value:.4f}")
# Out:
# Estadístico t: -3.5383
# P-valor: 0.0041

# %%
# Analizar los resultados 

#Para decidir, comparamos nuestro resultado con un p-valor (usualmente con un nivel de significancia  = 0.05).
#Resultado del p-valor: Para un t de -3.63 con 12 grados de libertad, 
# el p-valor es aproximadamente 0.0041.Comparación: Como $0.0041 < 0.05, el resultado es estadísticamente significativo.
# Conclusión técnica: Rechazamos la hipótesis nula (H0).Conclusión: Existe evidencia para afirmar que la Dieta 2 es más efectiva que la Dieta 1
# para la pérdida de peso en este grupo de personas.

# %% [markdown]
# ## ANOVA
#
# **ANOVA** (*Analysis of Variance - Análisis de variación*) Es una técnica estadística utilizada para comparar las medidas de dos o más grupos. La idea detrás de ANOVA es descomponer la variabilidad total de los datos en dos componentes: variabilidad entre grupos y variabilidad dentro de los grupos:
#
# - **Variabilidad entre grupos**: Esta variabilidad se refiere a las diferencias entre las medias del grupo. Si esta variabilidad es considerablemente mayor que la variabilidad dentro del grupo, podría ser una indicación de que al menos una de las medias del grupo es diferente.
# - **Variabilidad dentro del grupo**: Esta variabilidad se refiere a la dispersión de los datos dentro de cada grupo. Si todos los grupos tienen una variabilidad similar, entonces cualquier diferencia notable en las medias de los grupos podría considerarse significativa.
#
# Las hipótesis en ANOVA suelen incluir:
#
# - **Hipótesis nula** ($H₀$): Las medias de todos los grupos son iguales.
# - **Hipótesis alternativa** ($H₁$): Al menos una de las medias del grupo es diferente.
#
# Si el resultado de la prueba ANOVA es significativo (por ejemplo, un valor p inferior a un umbral como 0,05), esto sugiere que al menos la media de un grupo es diferente.

# %% [markdown]
# ## Ejercicio 2
#
# Un agricultor decide probar tres tipos diferentes de fertilizantes para determinar si alguno es superior en términos de producción de maíz. El agricultor planta maíz en 15 parcelas idénticas y utiliza los tres fertilizantes (5 parcelas para cada tipo). Al final de la temporada mide el rendimiento de maíz (en kg) de cada parcela, con el siguiente resultado:
#
# | Fertilizante 1 | Fertilizante 2 | Fertilizante 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# Con estos datos busca responder la siguiente pregunta: ¿Existe una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes?
#
# Para ayudarte, sigue los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba ANOVA.
# -Analizar las conclusiones.
# -Si un fertilizante es mejor que otro, ¿cómo podemos saberlo?

# %%
# 1. Enunciamos las hipótesis
#En ANOVA, las hipótesis siempre se plantean sobre la igualdad de todas las medias:
# Hipótesis Nula (H0): Las medias de rendimiento de los tres fertilizantes son iguales. No hay diferencia significativa.
# Hipótesis Alternativa (H1): Al menos una de las medias de rendimiento es diferente.

# %%
# 2.Realizamos la prueba ANOVA para comparar los tres grupos de fertilizantes
#Aqui los datos de rendimiento de los tres fertilizantes:
#fertilizante_1 = [20, 21, 20, 19, 20]
#fertilizante_2 = [22, 21, 23, 22, 21]
#fertilizante_3 = [24, 23, 22, 23, 24]

# %%
# 3. Realizamos los cálculos:

import scipy.stats as stats

f1 = [20, 21, 20, 19, 20]
f2 = [22, 21, 23, 22, 21]
f3 = [24, 23, 22, 23, 24]

f_stat, p_value = stats.f_oneway(f1, f2, f3)
print(f"F-Statistic: {f_stat:.4f}, P-value: {p_value:.4e}")
# Out:
# F-Statistic: 20.3158, P-value: 1.4048e-04

# %%
# 4. Analizamos los resultados:

#El p-valor resultante de este ejercicio es pequeño (mucho menor a 0.05).
# Conclusión: Rechazamos H0. Existe una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes.

# %%
# 5. Si el resultado es significativo, realizamos pruebas post-hoc para identificar qué grupos son diferentes entre sí.

#Prueba de Tukey (HSD): Es la más común. Compara los fertilizantes por parejas (1 vs 2, 1 vs 3, y 2 vs 3).

from statsmodels.stats.multicomp import pairwise_tukeyhsd
import pandas as pd

# Preparamos los datos 
df = pd.DataFrame({
    'rendimiento': [20, 21, 20, 19, 20, 22, 21, 23, 22, 21, 24, 23, 22, 23, 24],
    'fertilizante': ['F1']*5 + ['F2']*5 + ['F3']*5
})

# Realizamos la prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['rendimiento'],
                          groups=df['fertilizante'],
                          alpha=0.05)

print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#     F1     F2      1.8 0.0099 0.4572 3.1428   True
#     F1     F3      3.2 0.0001 1.8572 4.5428   True
#     F2     F3      1.4 0.0409 0.0572 2.7428   True
# --------------------------------------------------

# %%
# Interpretación de los resultados de Tukey:

# True: indica que hay una diferencia significativa entre esos los fertilizantes.
# Al medir el meandiff (la diferencia de medias), podemos determinar qué los fertilizantes son significativamente diferentes entre sí.
# El Ganador: El Fertilizante 3 es el mejor, ya que tiene el rendimiento promedio más alto y, según la prueba de Tukey, esta ventaja obedece a la efectividad del producto.
